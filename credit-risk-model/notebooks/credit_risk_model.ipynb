# %% [markdown]
# <a href="https://colab.research.google.com/github/vipulsurw/banking-analytics-portfolio/blob/main/credit-risk-model/notebooks/credit_risk_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🔹 1. Business Problem (Markdown cell)
# ## Credit Risk Modelling
#
# Financial institutions must assess the probability that a borrower will
# default on a loan. This project builds a supervised machine learning model
# to estimate default risk using applicant financial and demographic features.
#
# The goal is to:
# - Predict probability of default
# - Identify key risk drivers
# - Use interpretable models suitable for regulated environments

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    roc_auc_score,
    roc_curve
)

sns.set(style="whitegrid")
